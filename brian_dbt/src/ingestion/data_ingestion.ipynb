# %%
dbutils.widgets.multiselect("value","mino",["brian","chris","kingu","mino"])
st = list(dbutils.widgets.get("value"))
print(st)

# %%
st = dbutils.widgets.get("value")
st = st.replace("brian","chris").split(",")
print(st)

# %%
dbutils.widgets.text("catalog", "")
catalog = dbutils.widgets.get("catalog")

# %%
df = spark.sql(f'''SELECT * FROM samples.accuweather.{catalog} ''')

# %%
''''forecast_daily_calendar_metric '''

# %%
df.display( )

# %%
spark.conf.get("spark.databricks.workspaceUrl")

# %%
spark.range(5).toDF("name").display()
